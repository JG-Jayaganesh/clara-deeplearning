# %%
#!/usr/bin/python
# -*- coding: utf-8 -*-

"""
Pattern recognition  

"""

# import libraries

# python version libraries
from __future__ import absolute_import
from __future__ import division
from __future__ import print_function

# system libraries
import os

# data processing & array handling libraries 
import numpy as np
import pandas as pd

# deep learning libraries (backend - Theano)
from keras.models import Sequential
from keras.layers import Dense, Dropout, Activation
from keras.wrappers.scikit_learn import KerasClassifier
from keras.utils import np_utils

# machine learning libraries
from sklearn.model_selection import cross_val_score
from sklearn.model_selection import KFold
from sklearn.model_selection import StratifiedShuffleSplit

print(__doc__)

# fix random seed for reproducibility
seed = 7
np.random.seed(seed)

class Data_processing:

    # initialize
    def __init__(self):
        
        # set path
        path = '/home/azureuser/clara-deeplearning/data/'
        model_path = path + 'models/'
        if not os.path.exists(model_path): os.mkdir(model_path)
    
    # function to read CSV file
    def read(self, file):
        
        data = pd.read_csv(file)
        return data

    # function to clean CSV file
    def clean_data(self, data):
    
        # select numeric data alone from data object
        numeric_data = data.loc[:, data.dtypes != object]
    
        # select string data alone from data object to trim
        trim_data = data.select_dtypes(['object'])
    
        # trim all string objects
        trim_data = trim_data.apply(lambda x: x.str.strip())
    
        # merge numeric and string data in to data object
        data = pd.concat([numeric_data, trim_data], axis=1)
    
        # change column name to lower case
        data.columns = [x.lower() for x in data.columns]
        return data
    
    # define model
    def model(self):
    
        # create model
        model = Sequential()
        
        model.add(Dense(128, input_shape=(10,), kernel_initializer='normal', activation='sigmoid'))
        model.add(Dropout(0.5))
        model.add(Dense(25, kernel_initializer='normal', activation='softmax'))
        
        # compile model
        model.compile(loss='categorical_crossentropy', optimizer='adam', metrics=['accuracy'])
        
        # optimizer
        model.optimizer.lr=1e-5
        return model
    
    # save model and weights
    def model_weights(self):
        
        # serialize model to JSON
        model_json = model.to_json()
        with open(model_path + "model_type.json", "w") as json_file:
            json_file.write(model_json)
        
        # serialize weights to HDF5
        model.save_weights(model_path + 'model_type' + '.hdf5')
        
# function to drive the main flow
def drive():
    
    # instantiate class Data_processing 
    process = Data_processing()

    # read input file
    data = process.read("/home/azureuser/clara-deeplearning/data/test_74.csv")
    
    # clean input file
    data = process.clean_data(data)
    
    # remove junk columns
    data = data[data.columns[~data.columns.str.contains('unnamed:')]]
    
    # rename column 
    #data = data.rename(columns={'age category': 'age_category'})
    
    # fetch features
    X = data.ix[:,['age', 'status', 'family_size', 'location', 'budget']]
    print (X)
    dummy_X = pd.get_dummies(X)
    X = dummy_X.as_matrix()
    
    # fetch target
    dummy_y = pd.get_dummies(data['model'])
    y = dummy_y.as_matrix()
    
    # split train and test dataset
    sss = StratifiedShuffleSplit(n_splits=2, test_size=0.3, random_state=seed)
    
    for train_index, test_index in sss.split(X, y):
        train_X, test_X = X[train_index], X[test_index]
        train_y, test_y = y[train_index], y[test_index]
    
    print (train_X.shape)
    # call model
    model = process.model()
    
    # set batch size
    batch_size, verbose, validation_split, epochs = 350, 0, 0, 500
    
    # fit model    
    model.fit(train_X, 
              train_y, 
              epochs=epochs, 
              validation_split=validation_split, 
              batch_size=batch_size, 
              verbose=verbose)
    
    # validate accuracy
    loss, accuracy = model.evaluate(test_X, test_y)
    print("Accuracy = {:.2f}".format(accuracy))
    
    #predict = model.predict_classes(test_X)
    #print (dummy_y.columns[predict])
    #predict = model.predict_proba(test_X)
    
if __name__ == '__main__':
    drive()
# Out:
# Pattern recognition
#
#
#        age   status family_size location budget
# 0      <40   Single       Sedan       ED    Low
# 1      <40   Single       Sedan       LD    Low
# 2      <40   Single       Coupe       LD    Low
# 3      <40   Single   Cabriolet       LD    Low
# 4      <40   Single         SUV       LD    Low
# 5      <40  Married       Sedan       LD    Low
# 6      <40  Married       Coupe       LD    Low
# 7      <40  Married   Cabriolet       LD    Low
# 8      <40  Married         SUV       LD    Low
# 9      <40   Single       Sedan       CD    Low
# 10     <40   Single       Coupe       CD    Low
# 11     <40   Single   Cabriolet       CD    Low
# 12     <40   Single         SUV       CD    Low
# 13     <40  Married       Sedan       CD    Low
# 14     <40  Married       Coupe       CD    Low
# 15     <40  Married   Cabriolet       CD    Low
# 16     <40  Married         SUV       CD    Low
# 17     >40   Single       Sedan       LD    Low
# 18     >40   Single       Coupe       LD    Low
# 19     >40   Single   Cabriolet       LD    Low
# 20     >40   Single         SUV       LD    Low
# 21     >40  Married       Sedan       LD    Low
# 22     >40  Married       Coupe       LD    Low
# 23     >40  Married   Cabriolet       LD    Low
# 24     >40  Married         SUV       LD    Low
# 25     >40   Single       Sedan       CD    Low
# 26     >40   Single       Coupe       CD    Low
# 27     >40   Single   Cabriolet       CD    Low
# 28     >40   Single         SUV       CD    Low
# 29     >40  Married       Sedan       CD    Low
# ...    ...      ...         ...      ...    ...
# 84066  <40   Single       Coupe       CD   High
# 84067  <40   Single   Cabriolet       CD   High
# 84068  <40   Single         SUV       CD   High
# 84069  <40  Married       Sedan       CD   High
# 84070  <40  Married       Coupe       CD   High
# 84071  <40  Married   Cabriolet       CD   High
# 84072  <40  Married         SUV       CD   High
# 84073  >40   Single       Sedan       LD   High
# 84074  >40   Single       Coupe       LD   High
# 84075  >40   Single   Cabriolet       LD   High
# 84076  >40   Single         SUV       LD   High
# 84077  >40  Married       Sedan       LD   High
# 84078  >40  Married       Coupe       LD   High
# 84079  >40  Married   Cabriolet       LD   High
# 84080  >40  Married         SUV       LD   High
# 84081  >40   Single       Sedan       CD   High
# 84082  >40   Single       Coupe       CD   High
# 84083  >40   Single   Cabriolet       CD   High
# 84084  >40   Single         SUV       CD   High
# 84085  >40  Married       Sedan       CD   High
# 84086  >40  Married       Coupe       CD   High
# 84087  >40  Married   Cabriolet       CD   High
# 84088  >40  Married         SUV       CD   High
# 84089  >40  Married    Roadster       CD   High
# 84090  >40   Single    Roadster       CD   High
# 84091  >40  Married    Roadster       LD   High
# 84092  >40   Single    Roadster       LD   High
# 84093  <40  Married    Roadster       CD   High
# 84094  <40   Single    Roadster       CD   High
# 84095  >40  Married         SUV       ED   High
#
# [84096 rows x 5 columns]
# (58867, 14)
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-2-deff06a14234> in <module>()
#     160
#     161 if __name__ == '__main__':
# --> 162     drive()
#
# <ipython-input-2-deff06a14234> in drive()
#     149               validation_split=validation_split,
#     150               batch_size=batch_size,
# --> 151               verbose=verbose)
#     152
#     153     # validate accuracy
#
# /home/azureuser/anaconda3/lib/python3.6/site-packages/keras/models.py in fit(self, x, y, batch_size, epochs, verbose, callbacks, validation_split, validation_data, shuffle, class_weight, sample_weight, initial_epoch, **kwargs)
#     851                               class_weight=class_weight,
#     852                               sample_weight=sample_weight,
# --> 853                               initial_epoch=initial_epoch)
#     854
#     855     def evaluate(self, x, y, batch_size=32, verbose=1,
#
# /home/azureuser/anaconda3/lib/python3.6/site-packages/keras/engine/training.py in fit(self, x, y, batch_size, epochs, verbose, callbacks, validation_split, validation_data, shuffle, class_weight, sample_weight, initial_epoch, **kwargs)
#    1404             class_weight=class_weight,
#    1405             check_batch_axis=False,
# -> 1406             batch_size=batch_size)
#    1407         # prepare validation data
#    1408         if validation_data:
#
# /home/azureuser/anaconda3/lib/python3.6/site-packages/keras/engine/training.py in _standardize_user_data(self, x, y, sample_weight, class_weight, check_batch_axis, batch_size)
#    1294                                     self._feed_input_shapes,
#    1295                                     check_batch_axis=False,
# -> 1296                                     exception_prefix='model input')
#    1297         y = _standardize_input_data(y, self._feed_output_names,
#    1298                                     output_shapes,
#
# /home/azureuser/anaconda3/lib/python3.6/site-packages/keras/engine/training.py in _standardize_input_data(data, names, shapes, check_batch_axis, exception_prefix)
#     131                             ' to have shape ' + str(shapes[i]) +
#     132                             ' but got array with shape ' +
# --> 133                             str(array.shape))
#     134     return arrays
#     135
#
# ValueError: Error when checking model input: expected dense_2_input to have shape (None, 10) but got array with shape (58867, 14)
